# %% [markdown]
# # Clustering first attempt

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt 
import seaborn as sns

# import dataset
df_original_copy = pd.read_csv("dataset (missing + split)/train.csv", skipinitialspace=True)
df = pd.read_csv("dataset (missing + split)/train.csv", skipinitialspace=True) #this will be modified

# %%
#scaling, normalization
from sklearn.preprocessing import StandardScaler, MinMaxScaler
#kmeans, dbscan, hierarchical (sklearn)
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
#evaluation
from sklearn.metrics import silhouette_score
#import dataset
from sklearn.datasets import load_iris

#distance matrix (dbscan elbow, hierarchical)
from scipy.spatial.distance import pdist, squareform
# hierarchical (scipy)
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
#Changing udm to duration_ms and features_duration_ms from ms to min
df['duration_ms'] *= 1/6e4
df.rename(columns = {'duration_ms':'duration_min'}, inplace = True)

# %%
#Creating genre map -> mapping every genre into an int value in order to have correlation values. 
#Redoing Pearson correlation adding genre category
df['genre'].value_counts()
genre_map={"j-dance":0,"iranian":1,"brazil":2,"chicago-house":3,"forro":4,"idm":5,"indian":6,"study":7,"disney":8,"afrobeat":9,"mandopop":10,"techno":11,"sleep":12,"spanish":13,"j-idol":14,"industrial":15,"happy":16,"bluegrass":17,"black-metal":18,"breakbeat":19}
df.replace({'genre':genre_map}).corr(numeric_only=True).style.background_gradient(cmap='coolwarm',vmin=-1,vmax=1) #!!!
# Out:
# <style type="text/css">
# #T_b6df7_row0_col0, #T_b6df7_row0_col14, #T_b6df7_row1_col1, #T_b6df7_row2_col2, #T_b6df7_row3_col3, #T_b6df7_row4_col4, #T_b6df7_row5_col5, #T_b6df7_row6_col6, #T_b6df7_row7_col7, #T_b6df7_row8_col8, #T_b6df7_row9_col9, #T_b6df7_row10_col10, #T_b6df7_row11_col11, #T_b6df7_row12_col12, #T_b6df7_row13_col13, #T_b6df7_row14_col0, #T_b6df7_row14_col14, #T_b6df7_row15_col15, #T_b6df7_row16_col16, #T_b6df7_row17_col17, #T_b6df7_row18_col18, #T_b6df7_row19_col19, #T_b6df7_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b6df7_row0_col1, #T_b6df7_row1_col0, #T_b6df7_row1_col14, #T_b6df7_row5_col9, #T_b6df7_row9_col5, #T_b6df7_row14_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_b6df7_row0_col2, #T_b6df7_row0_col8, #T_b6df7_row2_col0, #T_b6df7_row2_col14, #T_b6df7_row3_col7, #T_b6df7_row7_col3, #T_b6df7_row8_col0, #T_b6df7_row8_col14, #T_b6df7_row9_col11, #T_b6df7_row11_col9, #T_b6df7_row12_col16, #T_b6df7_row14_col2, #T_b6df7_row14_col8, #T_b6df7_row16_col12 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_b6df7_row0_col3, #T_b6df7_row2_col16, #T_b6df7_row3_col0, #T_b6df7_row3_col14, #T_b6df7_row4_col7, #T_b6df7_row7_col4, #T_b6df7_row7_col10, #T_b6df7_row10_col7, #T_b6df7_row14_col3, #T_b6df7_row16_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b6df7_row0_col4, #T_b6df7_row4_col0, #T_b6df7_row4_col14, #T_b6df7_row14_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b6df7_row0_col5, #T_b6df7_row1_col13, #T_b6df7_row5_col0, #T_b6df7_row5_col8, #T_b6df7_row5_col13, #T_b6df7_row5_col14, #T_b6df7_row5_col17, #T_b6df7_row5_col18, #T_b6df7_row5_col20, #T_b6df7_row7_col11, #T_b6df7_row8_col5, #T_b6df7_row9_col19, #T_b6df7_row11_col7, #T_b6df7_row13_col1, #T_b6df7_row13_col5, #T_b6df7_row14_col5, #T_b6df7_row15_col17, #T_b6df7_row17_col5, #T_b6df7_row17_col15, #T_b6df7_row18_col5, #T_b6df7_row19_col9, #T_b6df7_row19_col20, #T_b6df7_row20_col5, #T_b6df7_row20_col19 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_b6df7_row0_col6, #T_b6df7_row2_col6, #T_b6df7_row4_col18, #T_b6df7_row6_col0, #T_b6df7_row6_col2, #T_b6df7_row6_col14, #T_b6df7_row10_col17, #T_b6df7_row14_col6, #T_b6df7_row17_col10, #T_b6df7_row18_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_b6df7_row0_col7, #T_b6df7_row0_col11, #T_b6df7_row6_col19, #T_b6df7_row7_col0, #T_b6df7_row7_col14, #T_b6df7_row7_col15, #T_b6df7_row8_col19, #T_b6df7_row9_col18, #T_b6df7_row11_col0, #T_b6df7_row11_col14, #T_b6df7_row11_col17, #T_b6df7_row14_col7, #T_b6df7_row14_col11, #T_b6df7_row15_col7, #T_b6df7_row15_col20, #T_b6df7_row17_col11, #T_b6df7_row18_col9, #T_b6df7_row19_col6, #T_b6df7_row19_col8, #T_b6df7_row20_col15 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_b6df7_row0_col9, #T_b6df7_row9_col0, #T_b6df7_row9_col14, #T_b6df7_row14_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b6df7_row0_col10, #T_b6df7_row2_col9, #T_b6df7_row7_col9, #T_b6df7_row8_col15, #T_b6df7_row9_col2, #T_b6df7_row9_col7, #T_b6df7_row10_col0, #T_b6df7_row10_col14, #T_b6df7_row14_col10, #T_b6df7_row15_col8, #T_b6df7_row17_col20, #T_b6df7_row20_col17 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_b6df7_row0_col12, #T_b6df7_row12_col0, #T_b6df7_row12_col14, #T_b6df7_row14_col12 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b6df7_row0_col13, #T_b6df7_row1_col15, #T_b6df7_row2_col3, #T_b6df7_row3_col2, #T_b6df7_row5_col6, #T_b6df7_row6_col5, #T_b6df7_row6_col11, #T_b6df7_row6_col18, #T_b6df7_row8_col11, #T_b6df7_row11_col6, #T_b6df7_row11_col8, #T_b6df7_row13_col0, #T_b6df7_row13_col14, #T_b6df7_row14_col13, #T_b6df7_row15_col1, #T_b6df7_row18_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_b6df7_row0_col15, #T_b6df7_row1_col12, #T_b6df7_row2_col19, #T_b6df7_row3_col18, #T_b6df7_row11_col19, #T_b6df7_row12_col1, #T_b6df7_row14_col15, #T_b6df7_row15_col0, #T_b6df7_row15_col14, #T_b6df7_row16_col18, #T_b6df7_row18_col3, #T_b6df7_row18_col16, #T_b6df7_row18_col20, #T_b6df7_row19_col2, #T_b6df7_row19_col11, #T_b6df7_row20_col18 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_b6df7_row0_col16, #T_b6df7_row0_col17, #T_b6df7_row14_col16, #T_b6df7_row14_col17, #T_b6df7_row16_col0, #T_b6df7_row16_col14, #T_b6df7_row17_col0, #T_b6df7_row17_col14 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_b6df7_row0_col18, #T_b6df7_row1_col5, #T_b6df7_row1_col19, #T_b6df7_row2_col15, #T_b6df7_row2_col18, #T_b6df7_row5_col1, #T_b6df7_row5_col10, #T_b6df7_row5_col11, #T_b6df7_row7_col12, #T_b6df7_row10_col5, #T_b6df7_row10_col20, #T_b6df7_row11_col5, #T_b6df7_row12_col7, #T_b6df7_row12_col19, #T_b6df7_row13_col19, #T_b6df7_row14_col18, #T_b6df7_row15_col2, #T_b6df7_row15_col19, #T_b6df7_row18_col0, #T_b6df7_row18_col2, #T_b6df7_row18_col14, #T_b6df7_row19_col1, #T_b6df7_row19_col12, #T_b6df7_row19_col13, #T_b6df7_row19_col15, #T_b6df7_row20_col10 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_b6df7_row0_col19, #T_b6df7_row1_col2, #T_b6df7_row2_col1, #T_b6df7_row2_col5, #T_b6df7_row5_col2, #T_b6df7_row7_col13, #T_b6df7_row10_col19, #T_b6df7_row11_col13, #T_b6df7_row11_col16, #T_b6df7_row13_col7, #T_b6df7_row13_col11, #T_b6df7_row14_col19, #T_b6df7_row16_col11, #T_b6df7_row16_col19, #T_b6df7_row17_col19, #T_b6df7_row19_col0, #T_b6df7_row19_col10, #T_b6df7_row19_col14, #T_b6df7_row19_col16, #T_b6df7_row19_col17 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_b6df7_row0_col20, #T_b6df7_row1_col18, #T_b6df7_row2_col11, #T_b6df7_row5_col12, #T_b6df7_row5_col15, #T_b6df7_row5_col16, #T_b6df7_row8_col18, #T_b6df7_row11_col2, #T_b6df7_row12_col5, #T_b6df7_row14_col20, #T_b6df7_row15_col5, #T_b6df7_row15_col18, #T_b6df7_row16_col5, #T_b6df7_row18_col1, #T_b6df7_row18_col8, #T_b6df7_row18_col15, #T_b6df7_row20_col0, #T_b6df7_row20_col14 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b6df7_row1_col3, #T_b6df7_row3_col1, #T_b6df7_row4_col5, #T_b6df7_row5_col4, #T_b6df7_row7_col20, #T_b6df7_row8_col12, #T_b6df7_row8_col13, #T_b6df7_row12_col8, #T_b6df7_row13_col8, #T_b6df7_row20_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_b6df7_row1_col4, #T_b6df7_row4_col1, #T_b6df7_row6_col20, #T_b6df7_row13_col20, #T_b6df7_row20_col6, #T_b6df7_row20_col13 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_b6df7_row1_col6, #T_b6df7_row6_col1, #T_b6df7_row6_col17, #T_b6df7_row17_col6 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_b6df7_row1_col7, #T_b6df7_row1_col16, #T_b6df7_row1_col17, #T_b6df7_row7_col1, #T_b6df7_row8_col16, #T_b6df7_row8_col17, #T_b6df7_row12_col20, #T_b6df7_row16_col1, #T_b6df7_row16_col8, #T_b6df7_row17_col1, #T_b6df7_row17_col8, #T_b6df7_row20_col12 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_b6df7_row1_col8, #T_b6df7_row3_col15, #T_b6df7_row8_col1, #T_b6df7_row15_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_b6df7_row1_col9, #T_b6df7_row8_col10, #T_b6df7_row9_col1, #T_b6df7_row10_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b6df7_row1_col10, #T_b6df7_row3_col20, #T_b6df7_row9_col12, #T_b6df7_row10_col1, #T_b6df7_row12_col9, #T_b6df7_row20_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_b6df7_row1_col11, #T_b6df7_row7_col18, #T_b6df7_row11_col1, #T_b6df7_row12_col18, #T_b6df7_row17_col18, #T_b6df7_row18_col7, #T_b6df7_row18_col12, #T_b6df7_row18_col17, #T_b6df7_row18_col19, #T_b6df7_row19_col18 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_b6df7_row1_col20, #T_b6df7_row3_col16, #T_b6df7_row4_col19, #T_b6df7_row6_col7, #T_b6df7_row7_col6, #T_b6df7_row11_col12, #T_b6df7_row12_col11, #T_b6df7_row16_col3, #T_b6df7_row19_col4, #T_b6df7_row20_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_b6df7_row2_col4, #T_b6df7_row4_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b6df7_row2_col7, #T_b6df7_row2_col12, #T_b6df7_row7_col2, #T_b6df7_row12_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b6df7_row2_col8, #T_b6df7_row8_col2, #T_b6df7_row12_col17, #T_b6df7_row17_col12 {
#   background-color: #cfdaea;
#   co

# %% [markdown]
# ## Clustering searching for genre division
# I want to cluster considering only 'musical features', that are the 'technical' ones. The idea is to find the already-given division by genre.
# It is interesting, in case this works, to do a **hierarchical clustering** in order to search for 'base' genres and subgenres.

# %% [markdown]
# The interesting features for the scope could be:
# - `duration_min`
# - `key` (discrete);
# - `mode` (discrete);
# - `speechiness`;
# - `acousticness`;
# - `instrumentalness`;
# - `tempo`;
# - `time_signature`;
# - `n_beats`;
# - `n_bars`;
# being the latter two highly correlated with `duration_ms`, just the former is necessary.
# also `genre` in order to check the results.
# Being those the interesting attributes, a goal-specific data understanding will be done only on this data.

# %% [markdown]
# ### Outlier criterion
# The outlier criterion for the following scope is composed by the following cut:
# - `time_sigmature` > 1.0, in order to select only _music tracks_, where the features taken into spot are all well-defined;
# - the first criterion ideally is enough but `sleep` tracks containing noise sounds often are bad-detected by the algorithm. Bc of that, in this first phase the `sleep` tracks are all excluded.

# %% [markdown]
# ### Data preparation

# %%
#Dealing with mode attribute missing values
#Computing p0 and p1 and filling missing values of mode attribute by sampling
#df['mode'].value_counts().plot(kind='bar', title='mode')
p0=df['mode'].value_counts()[0]/(len(df)-df['mode'].isnull().sum())
p1=df['mode'].value_counts()[1]/(len(df)-df['mode'].isnull().sum())
#print(f'p0={p0} , p1={p1}')
list_of_nan_indexes=df[df['mode'].isnull()].index.tolist()
for i in list_of_nan_indexes:
    #df.loc[i,'mode']
    #df.loc[['viper', 'sidewinder'], ['shield']] = 50
    if np.random.random() < p1:
        df.loc[i,'mode'] = 1.0
    else:
        df.loc[i,'mode'] = 0.0

# %%
#Dealing with time_signature attribute missing values
#Computing the array containing the probabilities of every outcome for time_signature
outcomes_of_time_signature = len(df['time_signature'].value_counts())
p_array=np.array(df['time_signature'].value_counts().sort_index(ascending=True)/(len(df)-df['time_signature'].isnull().sum()))
print(p_array)
#creating a dictionary containing the correspondance between value and sorted index
dict_ts = {0: 0.0, 1: 1.0, 2: 3.0, 3 : 4.0, 4 : 5.0}
list_of_nan_indexes_ts=df[df['time_signature'].isnull()].index.tolist()
#print(list_of_nan_indexes)
print(len(list_of_nan_indexes_ts))
from scipy.stats import multinomial 
#please forgive the dunb programming here, no real deal of time, only ~3000 points to be evaluated
for i in list_of_nan_indexes_ts:
    tmp = multinomial.rvs(1, p_array, size=1, random_state=None)
    array_tmp=np.where(tmp[0][:]==1)
    index=array_tmp[0][0] #implement a dict for the substitution
    df.loc[i,'time_signature'] = dict_ts[index]
# Out:
# [0.00711084 0.01151646 0.08981295 0.86257536 0.02898439]
# 2062

# %%
#Deleting outliers
df = df[(df['time_signature'] >1) & (df['genre'].str.contains('sleep')==False)]

# %%
#Selecting only the specific columns for the dataset
dfc=df[['duration_min','key', 'mode','speechiness','acousticness','instrumentalness','tempo','time_signature']]
dfc
# Out:
#        duration_min  key  mode  speechiness  acousticness  instrumentalness  \
# 0          4.029333    5   1.0       0.0975      0.302000          0.536000
# 1          7.400000    1   0.0       0.0805      0.283000          0.934000
# 2          5.558433    2   1.0       0.0397      0.000089          0.800000
# 3          4.496667    5   1.0       0.0765      0.066400          0.001270
# 4          5.127517    7   1.0       0.0539      0.000576          0.096900
# ...             ...  ...   ...          ...           ...               ...
# 14994      3.750700    1   0.0       0.0700      0.033400          0.002890
# 14995      7.200433    1   1.0       0.0558      0.016000          0.615000
# 14997      6.668183    1   0.0       0.0594      0.001830          0.857000
# 14998      3.287500    5   1.0       0.0531      0.000337          0.000014
# 14999      3.306817    6   1.0       0.0352      0.463000          0.000000
#
#          tempo  time_signature
# 0      142.221             4.0
# 1       75.596             4.0
# 2      116.628             4.0
# 3      140.880             4.0
# 4      143.956             4.0
# ...        ...             ...
# 14994  175.017             4.0
# 14995  117.319             4.0
# 14997  126.000             4.0
# 14998  160.044             4.0
# 14999   88.003             4.0
#
# [14106 rows x 8 columns]

# %% [markdown]
# ### Measure definition
# Being some of those attributes _categorical_, such as `time_signature`, it is necessary to define a custom distance, that encorporates the Euclidean distance for continuous attributes and the dissimilarity concept of distance for categorical attributes.

# %%
df.columns
# Out:
# Index(['name', 'duration_min', 'explicit', 'popularity', 'artists',
#        'album_name', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'features_duration_ms', 'time_signature', 'n_beats',
#        'n_bars', 'popularity_confidence', 'processing', 'genre'],
#       dtype='object')

# %% [markdown]
# The pitch class notation is round-shaped, so, for the `key` it is necessary to define the distance using the module operation.
# The `time_signature` attribute is only categorical, not ordinal.
#
# In some sense, it is the case, think about the following sentence: 'this song is two tones lower than this other'.

# %%
# Defining the metric
# When the attribute is continuous, then the euclidean measure is used,
# when the attribute is categorical, dissimilarity is computed. 
# In order to distinguish the kind of attribute for the metric, 
# a dict is created, it will be used inside the metric function.
attribute_type_dict = {'key':'key','mode':'categorical','speechiness':'continuous',
                       'acousticness':'continuous','instrumentalness':'continuous',
                       'tempo':'continuous','time_signature':'categorical'}  
def custom_distance(x1 : pd.core.series.Series, x2 : pd.core.series.Series) -> float:
    dissimilarity=np.array([])
    key_dissimilarity=np.array([])
    euclidean_distance=np.array([]) #will be filled of terms to be successively rooted
    for i in df.columns:
        if(attribute_type_dict[i] == 'categorical'): 
            #defining as metric the dissimilarity for categorical attributes
            #using nominal dissimilarity by now, I think is the right choice (think about it)
            if(x1[i]!=x2[i]):
                distance+=1
        elif(attribute_type_dict[i] == 'key'):
            #this needs a particular distance
             tmp = np.abs(x1[i]-x2[i])
             if tmp <=6:
                 np.append(key_dissimilarity, tmp)
             else:
                 np.append(key_dissimilarity, tmp%12)
        elif(attribute_type_dict[i] == 'continuous'): 
            #defining the std Euclidean metric for continuous attributes
            np.append(euclidean_distance, (x1[i]-x2[i])**2)

# %% [markdown]
# ### Normalization (or, standardization)
# It is necessary to choose a type of normalization. Looking at the distributions of the attributes for the scope, it is possible to decide with some criteria, see: https://developers.google.com/machine-learning/data-prep/transform/normalization?hl=en .

# %%
# let's look at distributions
sns.pairplot(dfc,diag_kind='kde')
#kde is the distribution command for diagonal plot
plt.show()

# %% [markdown]
# Being none of them really uniform, the chosen normalization is the _z-score_ normalization.

# %%
X = dfc.values
y = np.array(df['genre'])
y_mapped = pd.DataFrame(y).iloc[:,0]
#y_map = genre_map
#y_mapped = pd.DataFrame(y).iloc[:,0].map(y_map)
dfc.head()
# Out:
#    duration_min  key  mode  speechiness  acousticness  instrumentalness  \
# 0      4.029333    5   1.0       0.0975      0.302000           0.53600
# 1      7.400000    1   0.0       0.0805      0.283000           0.93400
# 2      5.558433    2   1.0       0.0397      0.000089           0.80000
# 3      4.496667    5   1.0       0.0765      0.066400           0.00127
# 4      5.127517    7   1.0       0.0539      0.000576           0.09690
#
#      tempo  time_signature
# 0  142.221             4.0
# 1   75.596             4.0
# 2  116.628             4.0
# 3  140.880             4.0
# 4  143.956             4.0

# %%
#performing z-score normalization
scaler = StandardScaler()
scaler.fit(X)
X_scal = scaler.transform(X)

# %%
#just for check, plotting one of the attributes after normalization
i = 1
sns.histplot(X_scal[:,i])
plt.title(dfc.columns[i])
plt.xlabel("Standardized values (zscore)")
plt.show()

# %%
kmeans = KMeans(n_clusters=6, n_init=10, max_iter=100, random_state=94)
kmeans.fit(X_scal)
# Out:
# KMeans(max_iter=100, n_clusters=6, n_init=10, random_state=94)

# %%
kmeans.labels_
# Out:
# array([ 8,  4,  8, ...,  4, 16,  7], dtype=int32)

# %%
print('SSE', kmeans.inertia_) #kmeans.inertia_ is the SSE value
print('Silhouette', silhouette_score(X_scal, kmeans.labels_))
# Out:
# SSE 66649.16500331127
# Silhouette 0.174379244708828

# %%
# %%time
sse_list = []
#Trying different K values for K-means
for k in range(1, 200):
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=100)
    kmeans.fit(X_scal)
    sse_list.append(kmeans.inertia_)
# Out:
# CPU times: user 1h 9min 41s, sys: 8min 12s, total: 1h 17min 54s
# Wall time: 10min 2s

# %%
sliceList = sse_list[:20]
sns.lineplot(x=range(len(sliceList)), y=sliceList, marker='o')
plt.ylabel('SSE')
plt.xlabel('k')
plt.show()

# %% [markdown]
# Maybe 200 is enough. Tonight trying with 500 but no more, I think makes no sense to cluster in 500 categories, is just for inspecting the trend.
# Inspecting 'by eye', the knee seems to be at around 10.

# %%
df['kmeans_labels'] = kmeans.labels_
plt.figure(figsize=(7,7))
sns.scatterplot(data=df, x="genre", y="kmeans_labels", hue=kmeans.labels_, 
                style='kmeans_labels', palette="bright")
plt.show()

# %% [markdown]
# This is not particularly interesting but the holes indicates that some genre does not stay in some cluster.
# I was hoping in something more interesting anyway.
# See correlation between `kmeans_labels` and the other attributes.

# %%
plt.figure(figsize=(6,6))
plt.title('Correlation with Pearson method - linear correlation coefficients')
sns.heatmap(dfc.corr(numeric_only=True), cmap="coolwarm", vmin=-1,fmt='.2f', vmax=1, annot=True)
# Out:
# <Axes: title={'center': 'Correlation with Pearson method - linear correlation coefficients'}>

# %%
sns.pairplot(dfc,diag_kind='kde')
#kde is the distribution command for diagonal plot
plt.show()

# %%
y_mapped
# Out:
# 0            j-dance
# 1            iranian
# 2        black-metal
# 3          bluegrass
# 4              happy
#             ...
# 14101         j-idol
# 14102            idm
# 14103         techno
# 14104      breakbeat
# 14105         indian
# Name: 0, Length: 14106, dtype: object

# %%
df['kmeans_labels'] = kmeans.labels_
sns.countplot(data=dfc, x='kmeans_labels', hue=y_mapped)
plt.show()
# Out:
# /var/folders/j1/wdxl892j6_94fw1s4vcb534c0000gn/T/ipykernel_1127/3420167838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['kmeans_labels'] = kmeans.labels_

# %% [markdown]
# ### Hierarchical trial before I start crying

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=None, n_clusters=8, metric='euclidean', linkage='complete', compute_distances=True, compute_full_tree=False)
model = model.fit(X_scal)

# %%
plt.title("Hierarchical Clustering Dendrogram")
plot_dendrogram(model, truncate_mode="lastp", above_threshold_color='r')
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %% [markdown]
# ### Cluster validity measure
# As described in the following article: https://pubmed.ncbi.nlm.nih.gov/23193245/, the 'safest' internal measure is the CVNN, where the integer $k$ has to be decided (doing multiple trials).
#
# As external measure, the idea is to confront the cluster labels with the `genre` classification.
